# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-slava/SII_7semestr/blob/main/SII_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("train_d.csv")
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599 entries, 0 to 598
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               599 non-null    int64
#  1   Glucose                   599 non-null    int64
#  2   BloodPressure             599 non-null    int64
#  3   SkinThickness             599 non-null    int64
#  4   Insulin                   599 non-null    int64
#  5   BMI                       599 non-null    float64
#  6   DiabetesPedigreeFunction  599 non-null    float64
#  7   Age                       599 non-null    int64
#  8   Outcome                   599 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 42.2 KB

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     129
# BloodPressure                44
# SkinThickness                51
# Insulin                     164
# BMI                         233
# DiabetesPedigreeFunction    437
# Age                          50
# Outcome                       2
# dtype: int64

# %%
col_name = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
df.set_axis(col_name, axis = 'columns')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 594            6      123             72             45      230  33.6
# 595            0      188             82             14      185  32.0
# 596            0       67             76              0        0  45.3
# 597            1       89             24             19       25  27.8
# 598            1      173             74              0        0  36.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.dropna(subset = ['BloodPressure'], inplace=True)
df.BloodPressure.unique()
df.BloodPressure = df.BloodPressure.replace('None', np.nan)

# %%
df[df['Age'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
# mean_age = round(df[(df['tag'] == 'да') & (df['Age'] == 'м')]['age'].mean())
mean_age = df.Age.mean()
mean_age
# Out:
# 33.29048414023372

# %%
df[df.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# 0
